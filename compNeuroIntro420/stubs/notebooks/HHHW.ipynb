# %%
# imports

# supply your constants and arrays and lists
T      = 
dt     = 
time   = 
V_0    = 
I      = 
V      = 
V[0]   = 
n      = 
m      = 
h      = 
E_Na   = 
E_K    = 
E_L    = 
g_Na   = 
g_K    = 
g_L    = 
C      = 


# the K gates cotrolled by n
def alpha_n(v): 
  # compute voltage dependent value
   return alpha_n
def beta_n(v):
    # compute voltage dependent value
   return beta_n
# the Na gates cotrolled by m
def alpha_m(v):
  # compute voltage dependent value
   return alpha_m
def beta_m(v):
  # compute voltage dependent value
   return beta_m
def alpha_h(v):
  # compute voltage dependent value
   return alpha_h
def beta_h(v):
  # compute voltage dependent value
   return beta_h

#can read what enumerate does here: https://docs.python.org/3.5/library/functions.html#enumerate
for j, t in enumerate(time):
   if 20 >= t >= 5:
      I[j] = 10
      
for j in range(1, len(time)):
   n[j] = n[j-1] + dt*(alpha_n(V[j-1])*(1-n[j-1])-beta_n(V[j-1])*n[j-1])
   m[j] = #need to fill in
   h[j] = #need to fill in
   V[j] = V[j-1] + #need to complete
    
#Plotting should work    
plot(time, V, time, I-25)
legend(('V','I'))
ylabel('V (mV)')
xlabel('Time (msec)')
show()

#Make a main function so that I can call it with different parameters
#see the effect on the action potential. Use default values for parameters.
