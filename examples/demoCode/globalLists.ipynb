# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
output = []

change = 0.05
P = 10

#position
currpos = -2
def newpos():
    return(currvel*change + currpos)
#velocity
currvel = 0 
def newvel ():
    return(curracc*change+currvel)
#acceleration
curracc = 2
def newacc():
    return(-(P)*currpos)

time = list(range(1,101))
for t in time:
    curracc = newacc()
    currvel = newvel()
    currpos = newpos()
    print(currpos)
    output.append(currpos)  

plt.plot(time, output)
# Out:
# -1.95
# -1.8512499999999998
# -1.70621875
# -1.51853203125
# -1.2928820117187498
# -1.0349099418945311
# -0.7510651235229491
# -0.4484436770632933
# -0.13461113867705515
# 0.18258667817610935
# 0.49521982807487114
# 0.7954724822717611
# 1.075838324411857
# 1.3293082084416565
# 1.5495453872604146
# 1.7310439313976624
# 1.8692663772499687
# 1.9607571636710257
# 2.003229021000307
# 1.9956201528045807
# 1.93812078078874
# 1.8321683892531806
# 1.6804117879862916
# 1.4866448920197455
# 1.2557118737527055
# 0.9933860586418481
# 0.7062255920649445
# 0.4014094856864172
# 0.08655814216572955
# -0.2304571549091014
# -0.5417110231112048
# -0.839422115735528
# -1.116147655466463
# -1.3649695038107366
# -1.5796671145597416
# -1.7548730474447531
# -1.8862071541436458
# -1.9703860819889474
# -2.005305357784525
# -1.9900919996354898
# -1.9251263414955673
# -1.8120325248182556
# -1.6536378950204875
# -1.4539023178472072
# -1.2178191827277467
# -0.9512905680400925
# -0.660979689151436
# ...
