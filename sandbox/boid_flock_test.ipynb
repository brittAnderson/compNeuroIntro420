# %%
import os

# %%
os.chdir("/home/britt/gitRepos/compNeuroIntro420/sandbox/.venv/lib/python3.10/site-packages/mesa/examples/basic/boid_flockers/")

# %%
os.getcwd()
# Out:
# '/home/britt/gitRepos/compNeuroIntro420/sandbox/.venv/lib/python3.10/site-packages/mesa/examples/basic/boid_flockers'

# %%
from  model import *

# %%
from  agents import *

# %%
from  app import *

# %%
model = BoidFlockers()

# %%
page = SolaraViz(
    model,
    components=[make_space_component(agent_portrayal=boid_draw, backend="matplotlib")],
    model_params=model_params,
    name="Boid Flocking Model",
)

# %%
page
# Out:
# Cannot show ipywidgets in text
